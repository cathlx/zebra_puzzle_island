# %%
from scripts.experiments import ExperimentManager

# %% [markdown]
# Все случайны

# %%
manager = ExperimentManager('configs/random_baseline.yaml')
path_to_results = manager.run_experiment()
manager.plot_results(figsize=(25, 10))

# %% [markdown]
# Первый рационален (ACO)

# %%
manager = ExperimentManager('configs/aco_1_rational.yaml')
path_to_results = manager.run_experiment()
manager.plot_results(figsize=(25, 10))
