# %%
from scripts.experiments import ExperimentManager

# %%
manager = ExperimentManager('configs/generated/all_random_gen.yaml')
path_to_results = manager.run_experiment(save_island_csv=True)
manager.plot_results(figsize=(15, 10))

# %%
# island settings saved here
people_path = path_to_results / 'island_schemas' / 'people.csv'
action_probs_path = path_to_results / 'island_schemas' / 'actions.csv'
distance_matrix_path = path_to_results / 'island_schemas' / 'distances.csv'

# %%
manager_aco = ExperimentManager('configs/generated/one_aco_gen.yaml')
path_to_results = manager_aco.run_experiment(save_island_csv=False)

# %%
manager_aco.plot_results(figsize=(15, 10))

# %% [markdown]
# С обязательными возвращениями

# %%
# all random
manager_mandatory_return_random = ExperimentManager('configs/generated/mandatory_return_random.yaml')
path_to_results = manager_mandatory_return_random.run_experiment(save_island_csv=False)
manager_mandatory_return_random.plot_results(figsize=(15, 10))

# %%
# 6 ACO, other random
manager_mandatory_return_random = ExperimentManager('configs/generated/mandatory_return_1_aco.yaml')
path_to_results = manager_mandatory_return_random.run_experiment(save_island_csv=False)
manager_mandatory_return_random.plot_results(figsize=(15, 10))
